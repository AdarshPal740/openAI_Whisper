# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-6ot7v_5d
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-6ot7v_5d
# ...
#      |████████████████████████████████| 5.3 MB 25.4 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 50.3 MB/s
# ...
#      |████████████████████████████████| 163 kB 64.3 MB/s
# ...
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175217 sha256=671cafd61f668a0ee4a27508510a44ddefe93cd4356e95f4733c0314b4ccb751
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_n0r503g/wheels/16/15/89/1c7bb31bd0006793a95549d04785121a8a36daad9158e1e43a
# Successfully built whisper
# ...

# %%
import whisper

# %%
model=whisper.load_model("large")
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [00:52<00:00, 59.1MiB/s]

# %%
out=model.transcribe("/content/mujhko-itna-bataye-koi-kaise-tujhse-dil-na-lagaye-koi-music-57668-58230-58231.mp3",language="hi")

# %%
out
# Out:
# {'text': ' कैसे तुझी से दिल न लगाए कोई रबा ने तुझी को पनाने ने कर दी है उसने की खाली तीजोरिया काजल की सिया ही से लिखी है तू ने जाने कितनो की लव स्टोरी आहां केसरिया तेरा इश्क है पिया रंडी जाऊं जो मैं हाथ लगाऊं दिन बीते सारा तेरी फिकर में रैन सारी तेरी खैर मनाऊं शिवा, इशा का मतलब जानते हो तू? पार्वेटी',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 8.0,
#    'text': ' कैसे तुझी से दिल न लगाए कोई',
#    'tokens': [50364,
#     31970,
#     43372,
#     45938,
#     21981,
#     8485,
#     97,
#     8703,
#     223,
#     3941,
#     251,
#     31881,
#     49316,
#     21981,
#     8485,
#     99,
#     33279,
#     46758,
#     8485,
#     101,
#     8485,
#     110,
#     3941,
#     245,
#     17937,
#     3941,
#     237,
#     31970,
#     33926,
#     3941,
#     230,
#     50764,
#     50914,
#     8485,
#     108,
#     3941,
#     105,
#     17937,
#     8485,
#     101,
#     21981,
#     8485,
#     97,
#     8703,
#     223,
#     3941,
# ...
